# %%
import os
import sys

sys.path.append('./src/')
from Model import *

# %%
model = Model()
model.load_model("./csv_models", "A")

# %%
model.solve_local_linear_problem()

# %%
model.clear_trajectory()
model.set_f0(model.LP_solution)
model.evolutionary_trajectory_with_drift(condition = "1", max_time = 1000, max_iter = 100000, sigma = 0.001, N_e = 10, track = True, label = 1 )
# Out:
# > Evolutionary simulation was completed
# (True, 0.6186931133270264)

# %%
plt.plot(model.MED_trajectory["t"], model.MED_trajectory["mu"])
